# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import google_api_key as g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Out:
# 'AIzaSyDruU_Xi3oOqaKE0uin8eL8Wvv_PU6huK8'

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0    Port Blair      IN  11.6667   92.7500     74.70        70
# 1        1     Jamestown      US  42.0970  -79.2353     21.00        86
# 2        2     Busselton      AU -33.6500  115.3333     68.00        81
# 3        3        Rorvik      NO  64.8621   11.2373     22.32        96
# 4        4  Krasnoselkup      RU  65.7000   82.4667    -42.21        75
#
#    Cloudiness  Wind Speed Current Description
# 0          39        7.70    scattered clouds
# 1          90        8.05          light snow
# 2          65        1.99       broken clouds
# 3         100       12.97     overcast clouds
# 4           0        6.22           clear sky

# %%
city_data_df.dtypes
# Out:
# City_ID                  int64
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
print('What kind of heat feels like vacation to you?')
print('Enter your maximum heat preference:')
maxHeat = float(input())
print('And how cold is too cold?')
print('Enter your minimum tolerable temperature:')
minHeat = float(input())
# Out:
# What kind of heat feels like vacation to you?
# Enter your maximum heat preference:
# 94
# And how cold is too cold?
# Enter your minimum tolerable temperature:
# 52

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
vacay_df = city_data_df.loc[(city_data_df['Max Temp'] <= maxHeat) & (city_data_df['Max Temp'] >= minHeat)]
len(vacay_df)
# Out:
# 384

# %%
# 4a. Determine if there are any empty rows.
vacay_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                4
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
vac_spots_df = vacay_df.dropna()
vac_spots_df.count()
# Out:
# City_ID                380
# City                   380
# Country                380
# Lat                    380
# Lng                    380
# Max Temp               380
# Humidity               380
# Cloudiness             380
# Wind Speed             380
# Current Description    380
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = vac_spots_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = np.nan
hotel_df.head(10)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 0     Port Blair      IN     74.70    scattered clouds  11.6667   92.7500
# 2      Busselton      AU     68.00       broken clouds -33.6500  115.3333
# 5       Mabaruma      GY     73.29     overcast clouds   8.2000  -59.7833
# 6        Camacha      PT     60.80          few clouds  33.0833  -16.3333
# 7   Punta Arenas      CL     55.40          light rain -53.1500  -70.9167
# 8          Adrar      MR     63.59    scattered clouds  20.5022  -10.0711
# 9     Bredasdorp      ZA     62.60     overcast clouds -34.5322   20.0403
# 10    Georgetown      MY     75.20          few clouds   5.4112  100.3354
# 12       Mataura      NZ     61.41     overcast clouds -46.1927  168.8643
# 13      Victoria      HK     66.00       broken clouds  22.2855  114.1577
#
#     Hotel Name
# 0          NaN
# 2          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# ...

# %%
#let's make sure this api call is working...
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius":5000,
    "type":"lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

hotels = requests.get(base_url, params=params)
hotels.json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwKf6tAM0e33QPNrFftxbxf3hEUlKOjpMV_E84autfc1ISJsSsPxv89oV1PBYyJrWkpqZM8jZaMUtFqXIbuXMycSiXxrKOWkXZHvHUikR83P8jF5kSMl_Y0JOfPqeZMwdBpFr0Jj7OKiI7RMC21wvl4-lWgfg-0p6VqiMo__sUyrcQgDl2mOscYiN9y48kkkLtpuGcbJHEvV30Bdo7sWQn6SdgkwGyRUgrpLGFlGssIfSCQM9GTkMxcALowDPrPr8Ec4doWb6Tgq4fUCW89E1aCugguv9CYD8bJ2HO7ZUb3-MfWWA3XGQ4fLbA2PEbuWrqRlWq5znxlmk0f5GdD5hbILu6MPPVO10JXgYWIv4OW4kPUujWJSBOKtfDpEjRmj6zgn_8SeKRWCyhQ8ctZ_n04z2UB07_u1gOLW5sJjWxt3l_zKNVg7FEx_',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291502},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
# ...

# %%
hotel_df['Lat']
# Out:
# 0      11.6667
# 2     -33.6500
# 5       8.2000
# 6      33.0833
# 7     -53.1500
#         ...
# 679     2.1000
# 680     5.6592
# 683    19.8000
# 684     4.9247
# 685    -8.7676
# Name: Lat, Length: 380, dtype: float64

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print("Got one!")
    except (IndexError):
        print("No hotel here. Onward.")
# Out:
# Got one!
# Got one!
# No hotel here. Onward.
# Got one!
# Got one!
# No hotel here. Onward.
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# No hotel here. Onward.
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# No hotel here. Onward.
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# No hotel here. Onward.
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# Got one!
# ...

# %%
hotel_df.head()
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0    Port Blair      IN     74.70    scattered clouds  11.6667   92.7500
# 2     Busselton      AU     68.00       broken clouds -33.6500  115.3333
# 5      Mabaruma      GY     73.29     overcast clouds   8.2000  -59.7833
# 6       Camacha      PT     60.80          few clouds  33.0833  -16.3333
# 7  Punta Arenas      CL     55.40          light rain -53.1500  -70.9167
#
#                           Hotel Name
# 0  Welcomhotel Bay Island Port Blair
# 2            Observatory Guest House
# 5                                NaN
# 6            Hotel Porto Santo & Spa
# 7          Hotel Dreams Del Estrecho

# %%
hotel_df.count()
# Out:
# City                   380
# Country                380
# Max Temp               380
# Current Description    380
# Lat                    380
# Lng                    380
# Hotel Name             357
# dtype: int64

# %%
hotel_df.isnull().sum()
# Out:
# City                    0
# Country                 0
# Max Temp                0
# Current Description     0
# Lat                     0
# Lng                     0
# Hotel Name             23
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df = hotel_df.dropna()
hotel_df.count()
# Out:
# City                   357
# Country                357
# Max Temp               357
# Current Description    357
# Lat                    357
# Lng                    357
# Hotel Name             357
# dtype: int64

# %%
hotel_df.head()
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0    Port Blair      IN      74.7    scattered clouds  11.6667   92.7500
# 2     Busselton      AU      68.0       broken clouds -33.6500  115.3333
# 6       Camacha      PT      60.8          few clouds  33.0833  -16.3333
# 7  Punta Arenas      CL      55.4          light rain -53.1500  -70.9167
# 9    Bredasdorp      ZA      62.6     overcast clouds -34.5322   20.0403
#
#                           Hotel Name
# 0  Welcomhotel Bay Island Port Blair
# 2            Observatory Guest House
# 6            Hotel Porto Santo & Spa
# 7          Hotel Dreams Del Estrecho
# 9           Bredasdorp Country Manor

# %%
# 8a. Create the output File (CSV)
output_file = 'WeatherPy_vacation.csv'
# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country Code</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
hotel_info
# Out:
# ['\n<dl>\n<dt>City Name</dt><dd>Port Blair</dd>\n<dt>Country Code</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>74.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Busselton</dd>\n<dt>Country Code</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Camacha</dd>\n<dt>Country Code</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>60.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Punta Arenas</dd>\n<dt>Country Code</dt><dd>CL</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>55.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City Name</dt><dd>Bredasdorp</dd>\n<dt>Country Code</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>62.6 °F</dd>\n</dl>\n',
# ...

# %%
locations.count()
# Out:
# Lat    357
# Lng    357
# dtype: int64

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# 11b. Display the figure
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
